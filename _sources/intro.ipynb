# %% [markdown]
# # $\Psi \Phi$

# %% [markdown]
# ```{figure} ./images/header.jpg
# :height: 300px
# :name: Chengyi (Jeff) Chen
#
# Hi, I'm Jeff and $\Psi \Phi$ (pronounced "sci-fi") is my technical blog dedicated to connecting seemingly disparate data science concepts. A majority of material in the blog includes summaries of Pattern Recognition and Machine Learning by Christopher M. Bishop, the best resource for learning probabilistic machine learning I can find.
# ```
